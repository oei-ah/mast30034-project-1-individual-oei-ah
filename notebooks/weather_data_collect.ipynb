# %% [markdown]
# https://www.ncei.noaa.gov/access/metadata/landing-page/bin/iso?id=gov.noaa.ncdc:C00516

# %%
import pandas as pd

df = pd.read_csv("https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2023/72364099999.csv")

# https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2023/

# %%
print(f"Number of instances: {len(df)}")
print(f"Number of features : {len(df.columns)}")
# Out:
# Number of instances: 365
# Number of features : 28

# %%
column_names_list = df.columns.tolist()
print(column_names_list)
# Out:
# ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'NAME', 'TEMP', 'TEMP_ATTRIBUTES', 'DEWP', 'DEWP_ATTRIBUTES', 'SLP', 'SLP_ATTRIBUTES', 'STP', 'STP_ATTRIBUTES', 'VISIB', 'VISIB_ATTRIBUTES', 'WDSP', 'WDSP_ATTRIBUTES', 'MXSPD', 'GUST', 'MAX', 'MAX_ATTRIBUTES', 'MIN', 'MIN_ATTRIBUTES', 'PRCP', 'PRCP_ATTRIBUTES', 'SNDP', 'FRSHTT']

# %%
df.tail(5)
# Out:
#          STATION        DATE   LATITUDE  LONGITUDE  ELEVATION  \
# 360  72364099999  2023-12-27  31.880444 -106.70325    1253.58
# 361  72364099999  2023-12-28  31.880444 -106.70325    1253.58
# 362  72364099999  2023-12-29  31.880444 -106.70325    1253.58
# 363  72364099999  2023-12-30  31.880444 -106.70325    1253.58
# 364  72364099999  2023-12-31  31.880444 -106.70325    1253.58
#
#                                                   NAME  TEMP  TEMP_ATTRIBUTES  \
# 360  DONA ANA CO INTERNATIONAL JETPORT ARPT SANTA T...  39.6               24
# 361  DONA ANA CO INTERNATIONAL JETPORT ARPT SANTA T...  41.5               24
# 362  DONA ANA CO INTERNATIONAL JETPORT ARPT SANTA T...  40.7               24
# 363  DONA ANA CO INTERNATIONAL JETPORT ARPT SANTA T...  39.7               24
# 364  DONA ANA CO INTERNATIONAL JETPORT ARPT SANTA T...  43.0               24
#
#      DEWP  DEWP_ATTRIBUTES  ...  MXSPD   GUST   MAX  MAX_ATTRIBUTES   MIN  \
# ...

# %%
import os

base_dir = '../data/raw'
weather_data_dir = os.path.join(base_dir, 'weather_data')
file_name = 'weather_raw.parquet'
os.makedirs(weather_data_dir, exist_ok=True)
file_path = os.path.join(weather_data_dir, file_name)

df.to_parquet(file_path, compression='gzip')
